# %%
import pandas as pd

# %%
df=pd.read_csv("../input/weather_brazil/conventional_weather_stations_inmet_brazil_1961_2019.csv",sep=';')

# %%
df.head(10)
# Out:
#    Estacao        Data  Hora  Precipitacao  TempBulboSeco  TempBulboUmido  \
# 0    82024  01/01/1961     0           NaN            NaN             NaN
# 1    82024  01/01/1961  1200           NaN           26.0            23.9
# 2    82024  01/01/1961  1800           NaN           32.3            27.0
# 3    82024  02/01/1961     0           NaN           25.8            24.6
# 4    82024  02/01/1961  1200          16.0           26.8            24.0
# 5    82024  02/01/1961  1800           NaN           32.6            27.2
# 6    82024  03/01/1961     0           NaN           28.3            26.2
# 7    82024  03/01/1961  1200           0.0           26.8            23.9
# 8    82024  03/01/1961  1800           NaN           32.3            25.7
# 9    82024  04/01/1961     0           NaN           28.7            25.3
#
#    TempMaxima  TempMinima  UmidadeRelativa  PressaoAtmEstacao  PressaoAtmMar  \
# ...

# %%
df['Date']= pd.to_datetime(df['Data']) 

df_20l6=df[(df['Date'] > '01/01/2016') & (df['Date'] <= '31/12/2016')]

# %%
df_20l6.head()
# Out:
#        Estacao        Data  Hora  Precipitacao  TempBulboSeco  TempBulboUmido  \
# 44452    82024  02/01/2016     0           NaN           28.7             NaN
# 44453    82024  02/01/2016  1200           0.0           26.9             NaN
# 44454    82024  03/01/2016     0           NaN           27.8             NaN
# 44455    82024  03/01/2016  1200           0.0           27.8             NaN
# 44456    82024  04/01/2016     0           NaN           27.6             NaN
#
#        TempMaxima  TempMinima  UmidadeRelativa  PressaoAtmEstacao  ...  \
# 44452        28.2         NaN             68.0                NaN  ...
# 44453         NaN        25.3             76.0                NaN  ...
# 44454        28.3         NaN             63.0                NaN  ...
# 44455         NaN        24.5             72.0                NaN  ...
# 44456        29.2         NaN             77.0                NaN  ...
#
#        DirecaoVento  VelocidadeVento  Insolacao  Nebulosidade  \
# ...

# %%
#"VITORIA - ES";83648;-20.31;-40.31;36.2;"Estação Operante";"20/11/1923"

# %%
df_20l6['Estacao'].dtypes
df_20l6 = df_20l6.astype({'Estacao':'str'})

# %%
df_20l6.to_csv("../input/weather_brazil/conventional_weather_brazil_2016.csv",sep="\t")

# %%
df_20l6[df_20l6['Estacao']=='83648'].loc[(df_20l6['Date'] >= '2016-04-29')& (df_20l6['Date'] < '2016-04-30')]
# Out:
#         Estacao        Data  Hora  Precipitacao  TempBulboSeco  \
# 2868057   83648  29/04/2016     0           NaN           22.6
# 2868058   83648  29/04/2016  1200           0.0           22.8
# 2868059   83648  29/04/2016  1800           NaN           22.6
#
#          TempBulboUmido  TempMaxima  TempMinima  UmidadeRelativa  \
# 2868057            20.2        23.9         NaN             78.0
# 2868058            19.8         NaN        21.4             74.0
# 2868059            20.8         NaN         NaN             83.0
#
#          PressaoAtmEstacao  ...  DirecaoVento  VelocidadeVento  Insolacao  \
# 2868057             1013.6  ...          18.0              NaN        0.0
# 2868058             1013.2  ...          18.0              NaN        NaN
# 2868059             1010.6  ...          18.0              NaN        NaN
#
#          Nebulosidade  Evaporacao Piche  Temp Comp Media  \
# 2868057          10.0               4.1             22.5
# ...

# %%
df_20l6[df_20l6['Estacao']=='83648'].loc[(df_20l6['Date'] >= '2016-06-06')& (df_20l6['Date'] < '2016-06-07')]
# Out:
#         Estacao        Data  Hora  Precipitacao  TempBulboSeco  \
# 2868151   83648  06/06/2016     0           NaN           26.2
# 2868152   83648  06/06/2016  1200           0.0           26.2
# 2868153   83648  06/06/2016  1800           NaN           28.8
#
#          TempBulboUmido  TempMaxima  TempMinima  UmidadeRelativa  \
# 2868151            23.8        35.0         NaN             79.0
# 2868152            23.8         NaN        24.0             79.0
# 2868153            24.9         NaN         NaN             70.0
#
#          PressaoAtmEstacao  ...  DirecaoVento  VelocidadeVento  Insolacao  \
# 2868151             1009.2  ...          36.0              NaN        6.8
# 2868152             1009.9  ...          36.0              NaN        NaN
# 2868153             1006.3  ...           9.0              NaN        NaN
#
#          Nebulosidade  Evaporacao Piche  Temp Comp Media  \
# 2868151           0.0               5.0            27.16
# ...

# %%
#Temperature (in Kelvin), pressure (in
#hectopascal pressure units), humidity (in %), and wind speed (in m/s)
#were aggregated as each day.
